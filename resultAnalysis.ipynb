# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
allDirs = os.listdir("./experiments")

# %%
#

# %%
#areFiles = [os.path.join(os.path.abspath(os.path.curdir),os.path.join("experiments",f)) if (os.path.isfile(os.path.join(os.path.abspath(os.path.curdir),os.path.join("experiments",f))) == True) else None for f in os.listdir("./experiments")]
areFiles = [os.path.join(os.path.abspath(os.path.curdir),os.path.join("experiments",f)) for f in os.listdir("./experiments") if (os.path.isfile(os.path.join(os.path.abspath(os.path.curdir),os.path.join("experiments",f))) == True)]

# %%
areFiles
# Out:
# ['c:\\Users\\paulw\\OneDrive - Scientific Network South Tyrol\\STL Experiments\\experiments\\resultsAbsence1.csv',
#  'c:\\Users\\paulw\\OneDrive - Scientific Network South Tyrol\\STL Experiments\\experiments\\resultsAbsence2.csv',
#  'c:\\Users\\paulw\\OneDrive - Scientific Network South Tyrol\\STL Experiments\\experiments\\resultsAbsence3.csv',
#  'c:\\Users\\paulw\\OneDrive - Scientific Network South Tyrol\\STL Experiments\\experiments\\resultsResponse1.csv',
#  'c:\\Users\\paulw\\OneDrive - Scientific Network South Tyrol\\STL Experiments\\experiments\\resultsResponse2.csv',
#  'c:\\Users\\paulw\\OneDrive - Scientific Network South Tyrol\\STL Experiments\\experiments\\resultsResponse3.csv']

# %%
f0 = pd.read_csv(areFiles[0], sep=";", header=0, names=head)
head = ["runs", "avgTime", "std", "nTrials", "nObs", "timePerObs"]

# %%
areFiles[0].split("\\")[-1]
# Out:
# 'resultsAbsence1.csv'

# %%
allRuns = f0["runs"].apply(lambda s: s.replace("[","").replace("]","").split(" "))

# %%
#r= f0.groupby("nObs").agg({"runs":"sum"})#.apply(lambda s: s.replace("[","").replace("]","").split(" "))
#len(r)
#f0
# Out:
# 9

# %%
#f0 = pd.read_csv(areFiles[0], sep=";", header=0, names=head)
#head = ["runs", "avgTime", "std", "nTrials", "nObs", "timePerObs"]
#r= f0.groupby("nObs").agg({"runs":"sum"})#.apply(lambda s: s.replace("[","").replace("]","").split(" "))

#runData = []
#for k in range(len(r)):
#    r0 = r.iloc[k].str.replace(r"[", " ").str.replace(r"]"," ")
#    r0Arr = r0.str.strip().str.split(" ").iloc[0]
#    r0Runs = np.array([item for item in r0Arr if item]).astype(float)
#    [runData.append([r0.name, rItem]) for rItem in r0Runs]

# %%
#runData = []
#for k in range(len(r)):
#    r0 = r.iloc[k].str.replace(r"[", " ").str.replace(r"]"," ")
#    r0Arr = r0.str.strip().str.split(" ").iloc[0]
#    r0Runs = np.array([item for item in r0Arr if item]).astype(float)
#    [runData.append([r0.name, rItem]) for rItem in r0Runs]

# %%
#dfRun = pd.DataFrame(runData, columns=["nObs", "runTime"])

# %%
#dfRun["logTime"] = np.log2(dfRun["runTime"])
#dfRun["runTime"].apply(lambda l: "{:.2E}".format(l))

# %%
#bplot = sns.boxplot(data=dfRun, x="nObs", y="logTime")
#plt.ticklabel_format(axis='both', style='scientific')
#ax = plt.gca()
#ax.get_xaxis().get_major_formatter().set_scientific(True)
# Out:
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
#r0 = r.iloc[0].str.replace(r"[", " ").str.replace(r"]"," ")

# %%
#r0Arr = r0.str.strip().str.split(" ").iloc[0]
#r0Runs = np.array([item for item in r0Arr if item]).astype(float)

# %%
#r0Runs
# Out:
# array([0.0112444, 0.0116343, 0.0111879, 0.0148433, 0.0165011, 0.0110895,
#        0.010009 , 0.0135637, 0.0129537, 0.0141695, 0.0129038, 0.0123615,
#        0.0120439, 0.0114235, 0.0119109])

# %%
#sns.boxplot(data=f0, y="timePerObs", x="nObs")
#sns.boxplot(f0["timePerObs"], hue=f0["nObs"])
# Out:
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='nObs', ylabel='timePerObs'>

# %%
#fig, axs_ = plt.subplots(2)
#fig.set_figheight(12)
#fig.set_figwidth(15)

for f in areFiles:
    fname = f.split("\\")[-1]
    fig, axs_ = plt.subplots(2)
    fig.set_figheight(12)
    fig.set_figwidth(15)
    d = pd.read_csv(f, sep=";", header=0, names=head)
    axs_[0].plot(d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").values)
    axs_[1].plot(d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").values)
    fig.suptitle(f"Runtime statistics for {fname}")

    #axs_[[0,1,9].index(k)].plot(range(n),data[data[6]==k].iloc[0:n,2], ".-", linewidth=3, markersize=15, label="x")
    #plt.plot(range(n), np.full(n,300))
    #axs_[[0,1,9].index(k)].plot(range(n), np.full(n,300))
    #axs_[[0,1,9].index(k)].set_title(f"First {n} observations for Sensor {k}")
    

#plt.title("CO2 Concentration")
#fig.suptitle("CO2 Concentration in ppm")
#plt.savefig("./plots/co2ppm.png")
#plt.show()

# %%
#for f in areFiles:
#    fname = f.split("\\")[-1]
#    d = pd.read_csv(f, sep=";", header=None, names=head)
#    r= d.groupby("nObs").agg({"runs":"sum"})
#    print(r)
#    print(fname, len(r))

# %%
#f0 = pd.read_csv(areFiles[0], sep=";", header=0, names=head)
head = ["runs", "avgTime", "std", "nTrials", "nObs", "timePerObs"]
#r= f0.groupby("nObs").agg({"runs":"sum"})#.apply(lambda s: s.replace("[","").replace("]","").split(" "))

runData = []
#for k in range(len(r)):
#    r0 = r.iloc[k].str.replace(r"[", " ").str.replace(r"]"," ")
#    r0Arr = r0.str.strip().str.split(" ").iloc[0]
#    r0Runs = np.array([item for item in r0Arr if item]).astype(float)
#    [runData.append([r0.name, rItem]) for rItem in r0Runs]

#fig, axs_ = plt.subplots(2)
#fig.set_figheight(12)
#fig.set_figwidth(15)

for f in areFiles:
    fname = f.split("\\")[-1]
    fig, axs_ = plt.subplots(2)
    fig.set_figheight(12)
    fig.set_figwidth(15)
    d = pd.read_csv(f, sep=";", header=None, names=head)
    axs_[0].plot(d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").values)
    axs_[1].plot(d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").values)
    fig.suptitle(f"Runtime statistics for {fname}")


    #f0 = pd.read_csv(f, sep=";", header=0, names=head)
    #head = ["runs", "avgTime", "std", "nTrials", "nObs", "timePerObs"]
    r= d.groupby("nObs").agg({"runs":"sum"})#.apply(lambda s: s.replace("[","").replace("]","").split(" "))

    for k in range(len(r)):
        #print()
        r0 = r.iloc[k].str.replace(r"[", " ").str.replace(r"]"," ")
        r0Arr = r0.str.strip().str.split(" ").iloc[0]
        r0Runs = np.array([item for item in r0Arr if item]).astype(float)
        [runData.append([fname, r0.name, rItem]) for rItem in r0Runs]

    #axs_[[0,1,9].index(k)].plot(range(n),data[data[6]==k].iloc[0:n,2], ".-", linewidth=3, markersize=15, label="x")
    #plt.plot(range(n), np.full(n,300))
    #axs_[[0,1,9].index(k)].plot(range(n), np.full(n,300))
    #axs_[[0,1,9].index(k)].set_title(f"First {n} observations for Sensor {k}")
    

#plt.title("CO2 Concentration")
#fig.suptitle("CO2 Concentration in ppm")
#plt.savefig("./plots/co2ppm.png")
#plt.show()

# %%
dfPlot = pd.DataFrame(runData, columns=["FileName", "nObs", "runTime"])
dfPlot["logTime"] = np.log(dfPlot["runTime"])

# %%
interData_ = dfPlot.groupby(["FileName", "nObs"]).agg({"runTime":"mean"}).reset_index()

# %%
interData_
# Out:
#                 FileName     nObs     runTime
# 0    resultsAbsence1.csv       60    0.001755
# 1    resultsAbsence1.csv     3600    0.095595
# 2    resultsAbsence1.csv    86400    2.426554
# 3    resultsAbsence1.csv   172800    4.785855
# 4    resultsAbsence1.csv   259200    7.157465
# 5    resultsAbsence1.csv   432000   11.929346
# 6    resultsAbsence1.csv   604800   16.877488
# 7    resultsAbsence1.csv   864000   24.260284
# 8    resultsAbsence1.csv  1000000   29.340829
# 9    resultsAbsence2.csv       60    0.003944
# 10   resultsAbsence2.csv     3600    0.223647
# 11   resultsAbsence2.csv    86400    4.702477
# 12   resultsAbsence2.csv   172800    9.256465
# 13   resultsAbsence2.csv   259200   14.001491
# 14   resultsAbsence2.csv   432000   23.483816
# 15   resultsAbsence2.csv   604800   32.950264
# 16   resultsAbsence2.csv   864000   47.296846
# 17   resultsAbsence2.csv  1000000   55.283459
# 18   resultsAbsence3.csv       60    0.003950
# ...

# %%
interData_["timePerObs"] = interData_["runTime"]/interData_["nObs"]

# %%
plt.figure(figsize=(15,8))
#sns.boxplot(data=interData_, x="nObs", y="timePerObs", hue="FileName")
sns.lineplot(data=interData_, x="nObs", y="timePerObs", hue="FileName")
#plt.plot(interData_[n])
plt.title("Standardized runtime (time/nObs) per nObs")
plt.savefig("./runTimePerformance.png")
# Out:
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=dfPlot, x="nObs", y="logTime", hue="FileName")
# Out:
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=dfPlot, x="nObs", y="logTime", hue="FileName")
# Out:
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
#sns.boxplot(data=dfPlot, x="FileName", y="runTime", hue="nObs")
#plt.xticks(rotation=45)

# %%
dfPlot
# Out:
#                  FileName     nObs     runTime   logTime
# 0     resultsAbsence1.csv       60    0.002336 -6.059272
# 1     resultsAbsence1.csv       60    0.001796 -6.322249
# 2     resultsAbsence1.csv       60    0.001756 -6.344660
# 3     resultsAbsence1.csv       60    0.001867 -6.283530
# 4     resultsAbsence1.csv       60    0.001777 -6.332941
# ..                    ...      ...         ...       ...
# 655  resultsResponse3.csv  1000000  132.287088  4.884974
# 656  resultsResponse3.csv  1000000  132.035919  4.883074
# 657  resultsResponse3.csv  1000000  132.334450  4.885332
# 658  resultsResponse3.csv  1000000  134.117115  4.898713
# 659  resultsResponse3.csv  1000000  133.454307  4.893759
#
# [660 rows x 4 columns]

# %%
#d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 d_
#
# NameError: name 'd_' is not defined

# %%
fNames = [f.split("\\")[-1] for f in areFiles]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
#plt.style.use(['science', 'pgf'])

# %%
#formulas = [
#    "Absence[0,m](x[t] >=)",
#    "Response[0,m](x[t]>1000, x[t]<400)",
#    "Response[0,m][0,1](g[t]>500, dist(d[t]))",
#    "Response[0,m][]"
#]

"""
formulas = [
    "Absence(x[t]>1000)",
    "Absence(x[t]>1000)  ∧ \nAbsence(x[t]<150)",
    "Absence(x[t]>1000) ∧ \nAbsence(x[t]<150) ∧ \nAbsence(t[t]>40)",
    "Response(x[t]>1000, x[t]<400)",
    "Response(g[t]>500, dist(d[t]))",
    "Response(h[t]<40, G(x[t]<300))"
]
"""
formulas = [
    "Absence Test 1",
    "Absence Test 2",
    "Absence Test 3", 
    "Response Test 1",
    "Response Test 2", 
    "Response Test 3"
]

# %%
from matplotlib.ticker import FixedLocator

# %%
plt.figure(figsize=(15,8))

fig, axs_ = plt.subplots(1,2)
fig.set_figheight(6)
fig.set_figwidth(12)

plotTitles = [
    "Absence Constraints",
    "Response Constraints"
]

for i in range(2):
    axleg = []
    for j in range(3):
        #print(i, j+i*3)
        #axleg.append(f"{fNames[(j+i*3)]}")
        axleg.append(f"{formulas[(j+i*3)]}")
        d = pd.read_csv(areFiles[(j+i*3)], sep=";", header=None, names=head)
        axs_[i].plot(d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").values, marker=".", markersize=15, linewidth=3)
        axs_[i].set_ylabel("Time in Seconds")
        axs_[i].grid(True)
        axs_[i].set_xlabel("# Observations")
        #axs_[i].set_title(f"{1+j+i*3}) {fNames[(j+i*3)]}", y=-.15, pad=-25)
        axs_[i].set_title(f"{i+1}) {plotTitles[i]}", y=-.15, pad=-25)
        axs_[i].xaxis.set_minor_locator(FixedLocator([60, 60*60, 60*60*24, 60*60*24*2, 60*60*24*3, 60*60*24*5, 60*60*24*7, 60*60*24*10, 10**6]))
        axs_[i].ticklabel_format(style="plain")
        axs_[i].legend(axleg)
        #axs_[i,j].set_xticks(list(axs_[i,j].get_xticks()), rotation=45)
        #axs_[i,j].set_xticklabels(axs_[i,j].get_xticklabels(),rotation=45)


fig.tight_layout(pad=5)
#fig.title("Responses")
plt.savefig("./performance.png", dpi=600)
        #axs_[1].plot(d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").values)
        #d_ = dfPlot[dfPlot["FileName"] == fNames[(j+i*3)]]
        #axs_[i,j].plot()

# %%
plt.figure(figsize=(15,8))

fig, axs_ = plt.subplots(2)
fig.set_figheight(12)
fig.set_figwidth(10)

plotTitles = [
    "Absence Constraints",
    "Response Constraints"
]

for i in range(2):
    axleg = []
    for j in range(3):
        #print(i, j+i*3)
        axleg.append(f"{fNames[(j+i*3)]}")
        d = pd.read_csv(areFiles[(j+i*3)], sep=";", header=None, names=head)
        axs_[i].plot(d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").values, marker=".", markersize=15, linewidth=3)
        axs_[i].set_ylabel("Time in Seconds")
        axs_[i].grid(True)
        axs_[i].set_xlabel("# Observations")
        #axs_[i].set_title(f"{1+j+i*3}) {fNames[(j+i*3)]}", y=-.15, pad=-25)
        axs_[i].set_title(f"{i+1}) {plotTitles[i]}", y=-.15, pad=-25)
        axs_[i].xaxis.set_minor_locator(FixedLocator([60, 60*60, 60*60*24, 60*60*24*2, 60*60*24*3, 60*60*24*5, 60*60*24*7, 60*60*24*10, 10**6]))
        axs_[i].ticklabel_format(style="plain")
        axs_[i].legend(axleg)
        #axs_[i,j].set_xticks(list(axs_[i,j].get_xticks()), rotation=45)
        #axs_[i,j].set_xticklabels(axs_[i,j].get_xticklabels(),rotation=45)


fig.tight_layout(pad=5)
#plt.savefig("./performance2.png", dpi=600)
        #axs_[1].plot(d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").values)
        #d_ = dfPlot[dfPlot["FileName"] == fNames[(j+i*3)]]
        #axs_[i,j].plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[160], line 3
#       1 plt.figure(figsize=(15,8))
# ----> 3 fig, axs_ = plt.subplots((1,2))
#       4 fig.set_figheight(12)
#       5 fig.set_figwidth(10)
#
# File c:\Users\paulw\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1599, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1455 """
#    1456 Create a figure and a set of subplots.
#    1457
#    (...)
#    1596
#    1597 """
#    1598 fig = figure(**fig_kw)
# -> 1599 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1600                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1601                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1602                    width_ratios=width_ratios)
#    1603 return fig, axs
#
# ...

# %%
plt.figure(figsize=(15,8))

fig, axs_ = plt.subplots(2,3)
fig.set_figheight(12)
fig.set_figwidth(30)

for i in range(2):
    for j in range(3):
        #print(i, j+i*3)
        d = pd.read_csv(areFiles[(j+i*3)], sep=";", header=None, names=head)
        axs_[i,j].plot(d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "avgTime"]].groupby(by="nObs").mean().sort_values(by="nObs").values, marker=".", markersize=10, color="b")
        axs_[i,j].set_ylabel("Time in Seconds")
        axs_[i,j].grid(True)
        axs_[i,j].set_xlabel("# Observations")
        axs_[i,j].set_title(f"{1+j+i*3}) {fNames[(j+i*3)]}", y=-.15, pad=-25)
        axs_[i,j].xaxis.set_minor_locator(FixedLocator([60, 60*60, 60*60*24, 60*60*24*2, 60*60*24*3, 60*60*24*5, 60*60*24*7, 60*60*24*10, 10**6]))
        axs_[i,j].ticklabel_format(style="plain")
        #axs_[i,j].set_xticks(list(axs_[i,j].get_xticks()), rotation=45)
        #axs_[i,j].set_xticklabels(axs_[i,j].get_xticklabels(),rotation=45)


fig.tight_layout(pad=5)
plt.savefig("./performance2.png", dpi=600)
        #axs_[1].plot(d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").index.values, d.loc[:,["nObs", "timePerObs"]].groupby(by="nObs").mean().sort_values(by="nObs").values)
        #d_ = dfPlot[dfPlot["FileName"] == fNames[(j+i*3)]]
        #axs_[i,j].plot()

# %%
sns.lineplot(data=dfPlot.groupby(["FileName", "nObs"]).mean().reset_index(), x="nObs", y="runTime", hue="FileName")
plt.title("Total Runtime (in s) for the Experiments") 
plt.savefig("./runTime.png")
# Out:
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
sns.lineplot(data=dfPlot.groupby(["FileName", "nObs"]).mean().reset_index(), x="nObs", y="logTime", hue="FileName")
plt.title("Total Runtime (in s) for the Experiments") 
plt.savefig("./runTime.png")
# Out:
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\paulw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...
